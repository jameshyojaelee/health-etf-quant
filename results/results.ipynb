# %% [markdown]
# # Results Snapshot
# Precomputed summaries, plots, and caveats for healthcare strategies.

# %%
import pandas as pd
from pathlib import Path
from IPython.display import Image, display

results_dir = Path('results')
summary = pd.read_csv(results_dir / 'strategy_summary.csv')
summary

# %% [markdown]
# ## Equity Curves
# Rotation and regime LS compared to benchmarks.

# %%
display(Image(filename=str(results_dir / 'equity_curves.png')))

# %% [markdown]
# ## Metrics (CAGR, Sharpe)
# Bar chart of core performance metrics.

# %%
display(Image(filename=str(results_dir / 'metrics_bar.png')))

# %% [markdown]
# ## Factor Exposure and Caveats
# - Load `data_processed/ff_factors_monthly.csv` to run factor regressions (see `run_strategies.py`).
# - Interpret alpha vs. market/size/value/profitability/investment betas; small alpha with large betas suggests factor tilt.
# - Caveats: simple signals, no slippage modeling beyond turnover bps, and macro thresholds are heuristic.
